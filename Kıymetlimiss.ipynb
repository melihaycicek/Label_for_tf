# %% [markdown]
# <a href="https://colab.research.google.com/github/melihaycicek/Label_for_tf/blob/master/K%C4%B1ymetlimiss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pip
# !pip install --upgrade protobuf

# %%
# %tensorflow_version 1.15==gpu
import tensorflow as tf
print(tf.__version__)

# !pip install numpy
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15==gpu`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# ...

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7410 sha256=5d1304043987c62b0e5a35810c8e0911182d8e3a64bffc25deea1b407f7953a9
#   Stored in directory: /root/.cache/pip/wheels/6e/f8/83/534c52482d6da64622ddbf72cd93c35d2ef2881b78fd08ff0c
# Successfully built gputil
# ...
# Gen RAM Free: 12.5 GB  | Proc size: 469.6 MB
# GPU RAM Free: 15005MB | Used: 104MB | Util   1% | Total 15109MB

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# change to working tensorflow directory on the drive
# %cd '/content/gdrive/My Drive/models/'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/models

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# %cd /content/gdrive/My Drive/models/research/
# !protoc object_detection/protos/*.proto --python_out=.

import os
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/models/research/:/content/gdrive/My Drive/models/research/slim'

# !python setup.py build
# !python setup.py install
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-tk is already the newest version (2.7.17-1~18.04).
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 13 not upgraded.
# Need to get 1,615 kB of archives.
# After this operation, 8,907 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python-bs4 all 4.6.0-1 [67.9 kB]
# ...

# %%
import time, psutil
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600)
# Out:
# Time remaining for this session is:  11.903013039959802

# %%
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
# !pip install tf_slim
# %cd /content/gdrive/My Drive/models/research/object_detection
os.environ['PYTHONPATH'] += ':/content/gdrive/My Drive/models/research/:/content/gdrive/My Drive/models/research/slim'

# !python train.py --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_pets.config --logtostderr
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# INFO:tensorflow:global step 4483: loss = 0.0474 (0.157 sec/step)
# I0228 18:26:06.287625 139915746707328 learning.py:512] global step 4483: loss = 0.0474 (0.157 sec/step)
# INFO:tensorflow:global step 4484: loss = 0.0728 (0.157 sec/step)
# I0228 18:26:06.446118 139915746707328 learning.py:512] global step 4484: loss = 0.0728 (0.157 sec/step)
# INFO:tensorflow:global step 4485: loss = 0.0338 (0.157 sec/step)
# I0228 18:26:06.604118 139915746707328 learning.py:512] global step 4485: loss = 0.0338 (0.157 sec/step)
# INFO:tensorflow:global step 4486: loss = 0.0498 (0.157 sec/step)
# I0228 18:26:06.762120 139915746707328 learning.py:512] global step 4486: loss = 0.0498 (0.157 sec/step)
# INFO:tensorflow:global step 4487: loss = 0.0470 (0.164 sec/step)
# I0228 18:26:06.927678 139915746707328 learning.py:512] global step 4487: loss = 0.0470 (0.164 sec/step)
# INFO:tensorflow:global step 4488: loss = 0.0430 (0.158 sec/step)
# ...

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/faster_rcnn_inception_v2_pets.config --trained_checkpoint_prefix training/model.ckpt-6537 --output_directory new_graph
# Out:
# python3: can't open file 'export_inference_graph.py': [Errno 2] No such file or directory
